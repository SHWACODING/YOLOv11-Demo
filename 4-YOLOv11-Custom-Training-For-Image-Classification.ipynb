# %%
# !nvidia-smi
# Out:
# Mon Aug 11 19:31:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -U ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OQloyBEkIa5d3pBnt68C")
project = rf.workspace("poultrydiseasedetection").project("fowl-pox")
version = project.version(1)
dataset = version.download("folder")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

## Load Classification Model
model = YOLO('yolo11n-cls.pt')

## Train The Model On Our Data
results = model.train(
    data="/content/Fowl-pox-1",
    epochs=20,
    imgsz=640
)
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image

# %%
Image("/content/runs/classify/train2/results.png", width=650)

# %%
model = YOLO("/content/runs/classify/train2/weights/best.pt")

results = model("/content/test.jpg")

results[0].show()
# Out:
# image 1/1 /content/test.jpg: 640x640 fowlpox 1.00, fowlpox_split 0.00, 9.9ms
# Speed: 31.0ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model = YOLO("/content/runs/classify/train2/weights/best.pt")

results = model("/content/test2.jpg", save=True, conf=0.25)

results[0].show()
# Out:
# image 1/1 /content/test2.jpg: 640x640 fowlpox 1.00, fowlpox_split 0.00, 5.7ms
# Speed: 19.9ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=224x224>
